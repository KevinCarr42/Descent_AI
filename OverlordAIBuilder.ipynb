# %%
############### IMPORTS ###############
from descent_ai import *

############### FORMATTING ###############
from IPython.core.display import display, HTML
import matplotlib.style as style
style.use('dark_background')
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
ml1 = ['Beastman', 'Bane Spider', 'Manticore', 'Shade']
b1 = 'Dragon'
a = AIOverlord(ml1, b1)

# %%
filter1 = ['Beastman', 'Bane Spider']
filter2 = ['Beastman', 'Bane Spider', 'Dragon']
print(a.summary())
# Out:
# ***************************  MONSTERS  ***************************
#
# ------------------------------------------------------------------
# A: Beastman
# ------------------------------------------------------------------
#
# Target: Closest
# Attack Range: 0
#
# Combat AI Instructions
# ----------------------
# If at attack range: attack
# If within 4 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ------------------------------------------------------------------
# B: Bane Spider Minion
# ------------------------------------------------------------------
#
# Special Powers: 2X Spawn, 1HP
# Target: Closest
# Attack Range: 0 to 2
#
# Combat AI Instructions
# ----------------------
# If closer than 0 spaces: move to range > attack
# If 0 to 2 spaces: attack
# If within 6 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ------------------------------------------------------------------
# C: Manticore
# ...

# %%
md2 = {
    'Beastman': 'Skirmisher', 
    'Bane Spider': 'Minion', 
    'Manticore': 'Stalker', 
    'Shade': 'Controller', 
    'Dragon': 'Undead', 
    'boss': 'Dragon'
}

a2 = AIOverlord(md2)

# %%
filter1 = ['Beastman', 'Bane Spider']
filter2 = ['Beastman', 'Bane Spider', 'Dragon']
print(a.summary())
# Out:
# ***************************  MONSTERS  ***************************
#
# ------------------------------------------------------------------
# A: Beastman
# ------------------------------------------------------------------
#
# Target: Closest
# Attack Range: 0
#
# Combat AI Instructions
# ----------------------
# If at attack range: attack
# If within 4 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ------------------------------------------------------------------
# B: Bane Spider Minion
# ------------------------------------------------------------------
#
# Special Powers: 2X Spawn, 1HP
# Target: Closest
# Attack Range: 0 to 2
#
# Combat AI Instructions
# ----------------------
# If closer than 0 spaces: move to range > attack
# If 0 to 2 spaces: attack
# If within 6 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ------------------------------------------------------------------
# C: Manticore
# ...

# %%
print(a.summary(monsters_to_display=filter1))
# Out:
# ***************************  MONSTERS  ***************************
#
# ------------------------------------------------------------------
# A: Beastman
# ------------------------------------------------------------------
#
# Target: Closest
# Attack Range: 0
#
# Combat AI Instructions
# ----------------------
# If at attack range: attack
# If within 4 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ------------------------------------------------------------------
# B: Bane Spider Minion
# ------------------------------------------------------------------
#
# Special Powers: 2X Spawn, 1HP
# Target: Closest
# Attack Range: 0 to 2
#
# Combat AI Instructions
# ----------------------
# If closer than 0 spaces: move to range > attack
# If 0 to 2 spaces: attack
# If within 6 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ******************************************************************

# %%
print(a.summary(monsters_to_display=filter2))
# Out:
# ***************************  MONSTERS  ***************************
#
# ------------------------------------------------------------------
# A: Beastman
# ------------------------------------------------------------------
#
# Target: Closest
# Attack Range: 0
#
# Combat AI Instructions
# ----------------------
# If at attack range: attack
# If within 4 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# ------------------------------------------------------------------
# B: Bane Spider Minion
# ------------------------------------------------------------------
#
# Special Powers: 2X Spawn, 1HP
# Target: Closest
# Attack Range: 0 to 2
#
# Combat AI Instructions
# ----------------------
# If closer than 0 spaces: move to range > attack
# If 0 to 2 spaces: attack
# If within 6 spaces: move to range > attack
# Otherwise: move to range > attack (if possible)
#
# *****************************  BOSS  *****************************
#
# ...
