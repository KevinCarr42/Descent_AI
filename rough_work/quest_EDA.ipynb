# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

############### FORMATTING ###############
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.1f}'.format)
mpl.rcParams['figure.facecolor'] = 'white'
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_excel('monster power calcs - encounters.xlsx', sheet_name='quest_import')

# %%
print('QUEST TOTALS - STATISTICS')
display(df[df.encounter.str.contains('TOTAL')].describe().T.iloc[:, [3, 1, 7]])
# Out:
# QUEST TOTALS - STATISTICS
#                min  mean   max
# n_monsters    18.0  28.6  49.0
# monster_types  8.0  11.4  15.0
# total_power   68.0  89.4 150.0

# %%
print('QUEST AREAS - STATISTICS')
display(df[~df.encounter.str.contains('TOTAL')].describe().T.iloc[:, [3, 1, 7]])
# Out:
# QUEST AREAS - STATISTICS
#                min  mean  max
# n_monsters     1.0   6.1 18.0
# monster_types  1.0   3.5  8.0
# total_power    5.0  19.0 74.0

# %%
df.loc[~df.encounter.str.contains('TOTAL'), ['total_power']].plot(kind='bar', figsize=(16,6))
plt.title('Total Power By Encounter')
plt.show()

df.loc[~df.encounter.str.contains('TOTAL'), 'total_power'].hist(
    figsize=(16,6), 
    bins=[x*10 for x in range(9)],
)
plt.title('Encounter Power')
plt.show()

# %%
df.loc[~df.encounter.str.contains('TOTAL'), ['monster_types']].plot(kind='bar', figsize=(16,6))
plt.title('Number of Monster Types By Encounter')
plt.show()

df.loc[df.encounter.str.contains('TOTAL'), ['monster_types']].plot(kind='bar', figsize=(16,6))
plt.title('Number of Monster Types By Quest')
plt.show()

# %%
df.loc[~df.encounter.str.contains('TOTAL'), ['n_monsters']].plot(kind='bar', figsize=(16,6))
plt.title('Total Number of Monsters By Encounter')
plt.show()

df.loc[df.encounter.str.contains('TOTAL'), ['n_monsters']].plot(kind='bar', figsize=(16,6))
plt.title('Total Number of Monsters By Quest')
plt.show()

# %%
df.loc[~df.encounter.str.contains('TOTAL'), 'monster_types'].hist(
    figsize=(16,6), 
    bins=[x for x in range(9)],
)
plt.title('Number of Monster Types Per Encounter')
plt.show()

df.loc[~df.encounter.str.contains('TOTAL'), 'n_monsters'].hist(
    figsize=(16,6), 
    bins=[x*5 for x in range(6)],
)
plt.title('Number of Total Monsters Per Encounter')
plt.show()

# %%
df.loc[df.encounter.str.contains('TOTAL'), 'monster_types'].hist(
    figsize=(16,6), 
    bins=[x*2+6 for x in range(7)],
)
plt.title('Number of Monster Types Per Quest')
plt.show()

df.loc[df.encounter.str.contains('TOTAL'), 'n_monsters'].hist(
    figsize=(16,6), 
    bins=[x*5+10 for x in range(9)],
)
plt.title('Number of Total Monsters Per Quest')
plt.show()
