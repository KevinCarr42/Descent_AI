# %%
############### IMPORTS ###############
from descent_ai import *

############### FORMATTING ###############
from IPython.core.display import display, HTML
import matplotlib.style as style
style.use('dark_background')
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
d = DescentScenario()

# %%
d = DescentScenario()
d.create_quest()
d.show(show_boss=False)
# Out:
# creating map...
# distributing monsters...
# distributing terrain...
# distributing treasures...
# complete!

# %%
d.show(1)

# %%
d.regenerate_map()
d.show(show_boss=False)
# Out:
# creating map...
# distributing monsters...
# distributing terrain...
# distributing treasures...
# complete!

# %%
d.regenerate_terrain(False, 'wet')
d.show(show_boss=False)
# Out:
# distributing terrain...

# %%
d.regenerate_treasure()
d.show(show_boss=False)
# Out:
# distributing treasures...

# %%
d.regenerate_monsters(keep_monsters=True, keep_archetypes=True)
d.show(show_boss=False)
# Out:
# distributing monsters...

# %%
d.regenerate_monsters()
d.show(show_boss=False)
# Out:
# distributing monsters...

# %%
d.regenerate_terrain(False, 'hot')
d.show(show_boss=False)
# Out:
# distributing terrain...

# %%
d.regenerate_terrain(False, 'hot', True)
d.show(show_boss=True)
# Out:
# distributing terrain...
